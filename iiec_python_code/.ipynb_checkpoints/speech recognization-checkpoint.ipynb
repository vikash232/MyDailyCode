\x00\x0f\x00\x01\x00\xef\xff\xf4\xff\x00\x00\xfe\xff\xf9\xff\xfa\xff\x03\x00 \x00\x0e\x00\x17\x00 \x00\x19\x00\x0b\x00\xee\xff\xfb\xff\n\x00\n\x00\xf6\xff\xff\xff\x07\x00\xf2\xff\x06\x00\x01\x00\t\x00\x13\x00\xf7\xff\xf5\xff\x05\x00\r\t\x00\xfb\xff\xf5\xff\xe8\xff\xff\xff\x03\x00\x0c\x00\x03\x00\xf2\xff\xfe\xff\xf6\xff\x0e\x00\x11\x00\x02\x00\x0c\x00\xff\xff\t\x00\xf8\xff\xfc\xff\x00\x00\x02\x00\x19\x00\xff\xff\xf0\xff\xe7\xff\xf9\xff\x02\x00\n\x00\xfd\xff\t\x00\xf0\xff\xf9\xff\x05\x00\x06\x00\xfe\xff\x1b\x00\x1d\x00\xfa\xff\xe0\xff\xec\xff\xf7\xff\xfd\xff\x07\x00\n\x00\x00\x00\x06\x00\xfc\xff\xf9\xff\x05\x00\xfe\xff\xfd\xff\xef\xff\x01\x00\xf5\xff\n\r\x00\x10\x00\x17\x00\xfd\xff\xfe\xff\n\x00\xff\xff\x04\x00\x07\x00\t\x00\x07\x00\xfe\xff\x04\x00\x0c\x00\r\x00\x0b\x00\x01\x00\x08\x00\xfc\xff\x00\x00\t\x00\x08\x00\x03\x00\x1b\x00#\x00\xfd\xff!\x00\x15\x00\n\x00\x15\x00\xfa\xff\xff\xff\xfc\xff\x05\x00\xfc\xff\x05\x00\x10\x00\xfc\xff\xf5\xff\x06\x00\xfa\xff\x04\x00\x08\x00\x08\x00\x03\x00\x00\x00\x08\x00\x00\x00\x1b\x00\x0f\x00\r\x00\t\x00\xfd\xff\x05\x00\xff\xff\x08\x00\x1e\x00\x15\x00\x12\x00\x08\x00\ ...

# %%
r.recognize_google(audio)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1239         """Send a complete request to the server."""
# -> 1240         self._send_request(method, url, body, headers, encode_chunked)
#    1241
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1285             body = _encode(body, 'body')
# -> 1286         self.endheaders(body, encode_chunked=encode_chunked)
#    1287
#
# C:\ProgramData\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1234             raise CannotSendHeader()
# -> 1235         self._send_output(message_body, encode_chunked=encode_chunked)
#    1236
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1005         del self._buffer[:]
# -> 1006         self.send(msg)
#    1007
#
# C:\ProgramData\Anaconda3\lib\http\client.py in send(self, data)
#     945             if self.auto_open:
# --> 946                 self.connect()
#     947             else:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in connect(self)
#     916         """Connect to the host and port specified in __init__."""
# --> 917         self.sock = self._create_connection(
#     918             (self.host,self.port), self.timeout, self.source_address)
#
# C:\ProgramData\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     786     err = None
# --> 787     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     788         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\speech_recognition\__init__.py in recognize_google(self, audio_data, key, language, show_all)
#     839         try:
# --> 840             response = urlopen(request, timeout=self.operation_timeout)
#     841         except HTTPError as e:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_open(self, req)
#    1378     def http_open(self, req):
# -> 1379         return self.do_open(http.client.HTTPConnection, req)
#    1380
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1352             except OSError as err: # timeout error
# -> 1353                 raise URLError(err)
#    1354             r = h.getresponse()
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>
#
# During handling of the above exception, another exception occurred:
#
# RequestError                              Traceback (most recent call last)
# <ipython-input-113-59c33ef07a2e> in <module>
# ----> 1 r.recognize_google(audio)
#
# C:\ProgramData\Anaconda3\lib\site-packages\speech_recognition\__init__.py in recognize_google(self, audio_data, key, language, show_all)
#     842             raise RequestError("recognition request failed: {}".format(e.reason))
#     843         except URLError as e:
# --> 844             raise RequestError("recognition connection failed: {}".format(e.reason))
#     845         response_text = response.read().decode("utf-8")
#     846
#
# RequestError: recognition connection failed: [Errno 11001] getaddrinfo failed

# %%
data = r.recognize_google(audio)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1239         """Send a complete request to the server."""
# -> 1240         self._send_request(method, url, body, headers, encode_chunked)
#    1241
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1285             body = _encode(body, 'body')
# -> 1286         self.endheaders(body, encode_chunked=encode_chunked)
#    1287
#
# C:\ProgramData\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1234             raise CannotSendHeader()
# -> 1235         self._send_output(message_body, encode_chunked=encode_chunked)
#    1236
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1005         del self._buffer[:]
# -> 1006         self.send(msg)
#    1007
#
# C:\ProgramData\Anaconda3\lib\http\client.py in send(self, data)
#     945             if self.auto_open:
# --> 946                 self.connect()
#     947             else:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in connect(self)
#     916         """Connect to the host and port specified in __init__."""
# --> 917         self.sock = self._create_connection(
#     918             (self.host,self.port), self.timeout, self.source_address)
#
# C:\ProgramData\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     786     err = None
# --> 787     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     788         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\speech_recognition\__init__.py in recognize_google(self, audio_data, key, language, show_all)
#     839         try:
# --> 840             response = urlopen(request, timeout=self.operation_timeout)
#     841         except HTTPError as e:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_open(self, req)
#    1378     def http_open(self, req):
# -> 1379         return self.do_open(http.client.HTTPConnection, req)
#    1380
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1352             except OSError as err: # timeout error
# -> 1353                 raise URLError(err)
#    1354             r = h.getresponse()
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>
#
# During handling of the above exception, another exception occurred:
#
# RequestError                              Traceback (most recent call last)
# <ipython-input-114-ebea0d735e7b> in <module>
# ----> 1 data = r.recognize_google(audio)
#
# C:\ProgramData\Anaconda3\lib\site-packages\speech_recognition\__init__.py in recognize_google(self, audio_data, key, language, show_all)
#     842             raise RequestError("recognition request failed: {}".format(e.reason))
#     843         except URLError as e:
# --> 844             raise RequestError("recognition connection failed: {}".format(e.reason))
#     845         response_text = response.read().decode("utf-8")
#     846
#
# RequestError: recognition connection failed: [Errno 11001] getaddrinfo failed

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
sp.getoutput("notepad")

# %%
import subprocess as sp

# %%
sp.getoutput("notepad")

# %%
pip install speech_recognition
